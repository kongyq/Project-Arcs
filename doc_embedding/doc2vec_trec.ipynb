# %% [markdown]
# # Doc2Vec to TREC Disk 1-5 articles

# %%
import logging, sys
# Create logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Create STDERR handler
handler = logging.StreamHandler(sys.stderr)
# ch.setLevel(logging.DEBUG)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler]

# %% [markdown]
# ## Basic Setup

# %% [markdown]
# Let's import Doc2Vec module.

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from pprint import pprint
import multiprocessing

# %% [markdown]
# ## Preparing the corpus

# %% [markdown]
# First, download the data of all TREC disk 1-5 from [here](https://trec.nist.gov/data/docs_eng.html)
# Second, convert the TREC format to TrecCorpus. TrecCorpus construct a corpus from a TREC disk.
#
# For more details on TrecCorpus, you should access docString of TrecCorpus class.

# %%
from trec.treccorpus import TrecCorpus

trecdata_path = "F:/Corpus/TrecData/"
# initialize dictionary with {} will significantly reduce the wait time for 8h, 
# since it will be done anyway when training doc2vec model, thus there is no need to be done here
trec = TrecCorpus(trecdata_path, dictionary={})
# Out:
# gensim.corpora.textcorpus - INFO - Input stream provided but dictionary already initialized

# %% [markdown]
# Define **TaggedTrecDocument** class to convert TrecCorpus into suitable form for Doc2Vec.

# %%
class TaggedTrecDocument(object):
    def __init__(self, trec):
        self.trec = trec
        self.trec.metadata = True
    def __iter__(self):
        for content, (doc_id, title) in self.trec.get_texts():
            yield TaggedDocument(content, [doc_id])

# %%
documents = TaggedTrecDocument(trec)

# %%
from utils import read_content

class TaggedLemmaDocument(object):
    def __init__(self, filename):
        self.filename = filename
    def __iter__(self):
        for content, (doc_id, title) in read_content(self.filename):
            yield TaggedDocument(content, [doc_id])

# %%
lemmatized = "f:/Corpus/lemmatized_trec_all.dat"
documents = TaggedLemmaDocument(lemmatized)

# %% [markdown]
# ## Preprocessing
# To set the same vocabulary size with original paper. We first calculate the optimal **min_count** parameter.

# %% [markdown]
# ## Training the Doc2Vec Model
# To train Doc2Vec model by several method, DBOW and DM, we define the list of models.

# %%
cores = multiprocessing.cpu_count()

model = Doc2Vec(dm=0, dbow_words=1, vector_size=1000, window=8, min_count=20, epochs=10, workers=cores)

# model = Doc2Vec(dm=1, dm_mean=1, vector_size=1000, window=8, min_count=20, epochs=10, workers=cores)
# 
# models = [
#     # PV-DBOW
#     Doc2Vec(dm=0, dbow_words=1, vector_size=300, window=8, min_count=10, epochs=10, workers=cores),
#     # PV-DM w/average
#     # Doc2Vec(dm=1, dm_mean=1, vector_size=300, window=8, min_count=10, epochs=10, workers=cores),
# ]

# %%
# %%time

model.build_vocab(documents)
print(str(model))
# models[1].reset_from(models[0])
# print(str(models[1]))
# Out:
# gensim.models.doc2vec - INFO - collecting all words and their counts
# gensim.models.doc2vec - INFO - PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #10000, processed 2380229 words (1985982/s), 53110 word types, 10000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #20000, processed 4766904 words (2670516/s), 74249 word types, 20000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #30000, processed 7123010 words (2705687/s), 91948 word types, 30000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #40000, processed 9521068 words (2689660/s), 106236 word types, 40000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #50000, processed 11856370 words (2609621/s), 118372 word types, 50000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #60000, processed 14265842 words (2003478/s), 129561 word types, 60000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #70000, processed 16576174 words (2567334/s), 140173 word types, 70000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #80000, processed 18924265 words (2450357/s), 150652 word types, 80000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #90000, processed 21283522 words (2511144/s), 160347 word types, 90000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #100000, processed 23686855 words (1840650/s), 169756 word types, 100000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #110000, processed 26091915 words (2435432/s), 179189 word types, 110000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #120000, processed 28504871 words (2655887/s), 188105 word types, 120000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #130000, processed 30915404 words (2594160/s), 196457 word types, 130000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #140000, processed 33281892 words (2156284/s), 204539 word types, 140000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #150000, processed 35667512 words (2054101/s), 211944 word types, 150000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #160000, processed 38065508 words (2139738/s), 219557 word types, 160000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #170000, processed 40518988 words (2385812/s), 227148 word types, 170000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #180000, processed 42966704 words (2270249/s), 234174 word types, 180000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #190000, processed 45421582 words (2069060/s), 241218 word types, 190000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #200000, processed 47835780 words (2114683/s), 247817 word types, 200000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #210000, processed 50230992 words (2222228/s), 254618 word types, 210000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #220000, processed 52670592 words (1997044/s), 260831 word types, 220000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #230000, processed 55088639 words (2215488/s), 267505 word types, 230000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #240000, processed 57498782 words (2255722/s), 274681 word types, 240000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #250000, processed 60586321 words (2224441/s), 284789 word types, 250000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #260000, processed 67564191 words (2485699/s), 293920 word types, 260000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #270000, processed 76444020 words (2931840/s), 300022 word types, 270000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #280000, processed 77658055 words (2702384/s), 312186 word types, 280000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #290000, processed 78288510 words (1890608/s), 319774 word types, 290000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #300000, processed 78919622 words (2161565/s), 325688 word types, 300000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #310000, processed 79610790 words (2150419/s), 331244 word types, 310000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #320000, processed 80292275 words (2056158/s), 336816 word types, 320000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #330000, processed 80978338 words (2101274/s), 342147 word types, 330000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #340000, processed 81624495 words (2102542/s), 346950 word types, 340000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #350000, processed 82326603 words (2075453/s), 351335 word types, 350000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #360000, processed 83038952 words (1723503/s), 355831 word types, 360000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #370000, processed 83751784 words (2097924/s), 359866 word types, 370000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #380000, processed 84413200 words (2081769/s), 364229 word types, 380000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #390000, processed 85102606 words (1980845/s), 368447 word types, 390000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #400000, processed 85769132 words (1872633/s), 372070 word types, 400000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #410000, processed 86461777 words (2201417/s), 375747 word types, 410000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #420000, processed 87157525 words (1765361/s), 379062 word types, 420000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #430000, processed 87848224 words (1689906/s), 382563 word types, 430000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #440000, processed 88492476 words (1794857/s), 385812 word types, 440000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #450000, processed 89165191 words (1988493/s), 389144 word types, 450000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #460000, processed 89890760 words (2131342/s), 393232 word types, 460000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #470000, processed 90563743 words (1963694/s), 396306 word types, 470000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #480000, processed 91278010 words (1885334/s), 399237 word types, 480000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #490000, processed 91946776 words (1264062/s), 402206 word types, 490000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #500000, processed 93287883 words (2224104/s), 410704 word types, 500000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #510000, processed 95607624 words (2470684/s), 422452 word types, 510000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #520000, processed 98112120 words (2216789/s), 436203 word types, 520000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #530000, processed 100941609 words (2342758/s), 449310 word types, 530000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #540000, processed 103949296 words (2422497/s), 462256 word types, 540000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #550000, processed 106498740 words (2356338/s), 469991 word types, 550000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #560000, processed 109241331 words (2675919/s), 484387 word types, 560000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #570000, processed 111753327 words (2428518/s), 492609 word types, 570000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #580000, processed 113993838 words (1989276/s), 500741 word types, 580000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #590000, processed 116739038 words (2422798/s), 510328 word types, 590000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #600000, processed 118738452 words (2388902/s), 516493 word types, 600000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #610000, processed 121839770 words (2505763/s), 527950 word types, 610000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #620000, processed 124082888 words (2303694/s), 533752 word types, 620000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #630000, processed 128012940 words (2734391/s), 544443 word types, 630000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #640000, processed 135921963 words (2464120/s), 559958 word types, 640000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #650000, processed 144311846 words (2483361/s), 571723 word types, 650000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #660000, processed 151413741 words (2667161/s), 582030 word types, 660000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #670000, processed 158999794 words (2915018/s), 591090 word types, 670000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #680000, processed 163565643 words (2822378/s), 596815 word types, 680000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #690000, processed 166984085 words (2781338/s), 601647 word types, 690000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #700000, processed 170534357 words (2473143/s), 605118 word types, 700000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #710000, processed 174204849 words (2452816/s), 609105 word types, 710000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #720000, processed 177601645 words (2378383/s), 612435 word types, 720000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #730000, processed 181180383 words (2489850/s), 618723 word types, 730000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #740000, processed 183288780 words (2061270/s), 625789 word types, 740000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #750000, processed 185306444 words (2261589/s), 631010 word types, 750000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #760000, processed 187482856 words (2108245/s), 636869 word types, 760000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #770000, processed 189643491 words (2252737/s), 641880 word types, 770000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #780000, processed 191736010 words (2314748/s), 646386 word types, 780000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #790000, processed 193914724 words (1841823/s), 651014 word types, 790000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #800000, processed 196035841 words (2284505/s), 655067 word types, 800000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #810000, processed 198035318 words (2368881/s), 658410 word types, 810000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #820000, processed 200092307 words (2099248/s), 661786 word types, 820000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #830000, processed 202103071 words (2160026/s), 665426 word types, 830000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #840000, processed 204091501 words (2634855/s), 668789 word types, 840000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #850000, processed 206055740 words (2071045/s), 671842 word types, 850000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #860000, processed 208128598 words (2433018/s), 675429 word types, 860000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #870000, processed 210139446 words (2562739/s), 678521 word types, 870000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #880000, processed 212067948 words (2284776/s), 681709 word types, 880000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #890000, processed 214037667 words (2458210/s), 684777 word types, 890000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #900000, processed 216086006 words (2081751/s), 688014 word types, 900000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #910000, processed 218052999 words (2204525/s), 690886 word types, 910000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #920000, processed 220027294 words (2021940/s), 693689 word types, 920000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #930000, processed 222129448 words (2291560/s), 696967 word types, 930000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #940000, processed 224227041 words (2141648/s), 700146 word types, 940000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #950000, processed 226667460 words (1969568/s), 706342 word types, 950000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #960000, processed 229181892 words (2433223/s), 712121 word types, 960000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #970000, processed 231667134 words (2389392/s), 717603 word types, 970000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #980000, processed 234167167 words (2609272/s), 722592 word types, 980000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #990000, processed 236685348 words (2024644/s), 727556 word types, 990000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1000000, processed 239203723 words (2153470/s), 732160 word types, 1000000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1010000, processed 241725400 words (2038729/s), 736757 word types, 1010000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1020000, processed 244209953 words (2204327/s), 741401 word types, 1020000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #
 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1500000, processed 367285185 words (2620500/s), 958295 word types, 1500000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1510000, processed 369622073 words (2323256/s), 962404 word types, 1510000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1520000, processed 372105260 words (2480102/s), 966801 word types, 1520000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1530000, processed 374372917 words (2346715/s), 970325 word types, 1530000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1540000, processed 376790945 words (2406364/s), 974218 word types, 1540000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1550000, processed 380028705 words (2265045/s), 977169 word types, 1550000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1560000, processed 380174692 words (1259908/s), 977642 word types, 1560000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1570000, processed 380331994 words (1398082/s), 978185 word types, 1570000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1580000, processed 380473286 words (1423281/s), 978654 word types, 1580000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1590000, processed 380619846 words (1203914/s), 979068 word types, 1590000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1600000, processed 380775718 words (1217509/s), 979601 word types, 1600000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1610000, processed 380908971 words (1179818/s), 980042 word types, 1610000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1620000, processed 381063375 words (1452948/s), 980562 word types, 1620000 tags
# gensim.models.doc2vec - INFO - PROGRESS: at example #1630000, processed 381206538 words (1358379/s), 981002 word types, 1630000 tags
# gensim.models.doc2vec - INFO - collected 981217 word types and 1634243 unique tags from a corpus of 1634243 examples and 381271295 words
# gensim.models.word2vec - INFO - Loading a fresh vocabulary
# gensim.models.word2vec - INFO - effective_min_count=20 retains 151574 unique words (15% of original 981217, drops 829643)
# gensim.models.word2vec - INFO - effective_min_count=20 leaves 378578534 word corpus (99% of original 381271295, drops 2692761)
# gensim.models.word2vec - INFO - deleting the raw counts dictionary of 981217 items
# gensim.models.word2vec - INFO - sample=0.001 downsamples 7 most-common words
# gensim.models.word2vec - INFO - downsampling leaves estimated 374500176 word corpus (98.9% of prior 378578534)
# gensim.models.base_any2vec - INFO - estimated required memory for 151574 words and 1000 dimensions: 8152199600 bytes
# gensim.models.word2vec - INFO - resetting layer weights
# Doc2Vec(dbow+w,d1000,n5,w8,mc20,s0.001,t12)
# Wall time: 3min 43s

# %% [markdown]
# Now we’re ready to train Doc2Vec of the TREC disk 1-5.

# %%
# %%time 
model.train(documents, total_examples=model.corpus_count, epochs=model.epochs)

## Save trained model
# Out:
# gensim.models.base_any2vec - INFO - training model with 12 workers on 151574 vocabulary and 1000 features, using sg=1 hs=0 sample=0.001 negative=5 window=8
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.03% examples, 75251 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.08% examples, 117354 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.12% examples, 113515 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.17% examples, 123054 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.20% examples, 126288 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.24% examples, 127256 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.27% examples, 126646 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.31% examples, 126393 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.35% examples, 127328 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.39% examples, 127196 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.43% examples, 129207 words/s, in_qsize 23, out_qsize 1
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.48% examples, 131745 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.51% examples, 128251 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.56% examples, 131491 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.60% examples, 131506 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.63% examples, 130332 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.68% examples, 131713 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.72% examples, 133032 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.75% examples, 131193 words/s, in_qsize 23, out_qsize 1
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.79% examples, 131855 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.84% examples, 132511 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.87% examples, 131942 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.91% examples, 132513 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.95% examples, 132926 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 0.99% examples, 132603 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.03% examples, 132953 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.07% examples, 133151 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.11% examples, 132776 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.15% examples, 133755 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.19% examples, 134001 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.22% examples, 133230 words/s, in_qsize 23, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.26% examples, 133518 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.30% examples, 133978 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1.34% examples, 134214 words/s, in_qsize 24, out_qsize 0
# gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 1
ensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 9 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 8 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 7 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 6 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 5 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 4 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 3 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# gensim.models.base_any2vec - INFO - EPOCH 10 - PROGRESS: at 100.00% examples, 140341 words/s, in_qsize 0, out_qsize 1
# gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# gensim.models.base_any2vec - INFO - EPOCH - 10 : training on 381271295 raw words (364734066 effective words) took 2598.9s, 140341 effective words/s
# gensim.models.base_any2vec - INFO - training on a 3812712950 raw words (3647351717 effective words) took 25442.0s, 143359 effective words/s
# Wall time: 7h 4min 2s

# %%
fname = "F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model"
model.save(fname)
# Out:
# gensim.utils - INFO - saving Doc2Vec object under F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model, separately None
# gensim.utils - INFO - storing np array 'syn1neg' to F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model.trainables.syn1neg.npy
# gensim.utils - INFO - storing np array 'vectors' to F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model.wv.vectors.npy
# gensim.utils - INFO - storing np array 'vectors_docs' to F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model.docvecs.vectors_docs.npy
# gensim.utils - INFO - saved F:/Models/Lemma_DBOW_2_doc2vec_trec_d1000_n5_w8_mc20_t12_e10_dbow.model

# %% [markdown]
# ## Similarity interface

# %% [markdown]
# After that, let's test both models! DBOW model show similar results with the original paper. First, calculating cosine similarity of "Machine learning" using Paragraph Vector. Word Vector and Document Vector are separately stored. We have to add .docvecs after model name to extract Document Vector from Doc2Vec Model.

# %%
for model in models:
    print(str(model))
    pprint(model.docvecs.most_similar(positive=["Machine learning"], topn=20))

# %% [markdown]
# DBOW model interpret the word 'Machine Learning' as a part of Computer Science field, and DM model as Data Science related field.
#
# Second, calculating cosine simillarity of "Lady Gaga" using Paragraph Vector.

# %%
for model in models:
    print(str(model))
    pprint(model.docvecs.most_similar(positive=["Lady Gaga"], topn=10))

# %% [markdown]
# DBOW model reveal the similar singer in the U.S., and DM model understand that many of Lady Gaga's songs are similar with the word "Lady Gaga".
#
# Third, calculating cosine simillarity of "Lady Gaga" - "American" + "Japanese" using Document vector and Word Vectors. "American" and "Japanese" are Word Vectors, not Paragraph Vectors. Word Vectors are already converted to lowercases by WikiCorpus.

# %%
for model in models:
    print(str(model))
    vec = [model.docvecs["Lady Gaga"] - model["american"] + model["japanese"]]
    pprint([m for m in model.docvecs.most_similar(vec, topn=11) if m[0] != "Lady Gaga"])

# %% [markdown]
# As a result, DBOW model demonstrate similar artists to Lady Gaga in Japan such as 'Perfume', who is the most famous idol in Japan. On the other hand, DM model results don't include Japanese artists in top 10 similar documents. It's almost the same with no vector calculated results.
#
# These results demonstrate that the DBOW employed in the original paper is outstanding for calculating similarity between Document Vector and Word Vector.
